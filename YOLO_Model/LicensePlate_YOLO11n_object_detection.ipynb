# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 30.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 127.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 66.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data= "/content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/data.yaml",  # path to dataset YAML
    epochs=2,  # number of training epochs
    imgsz=200,  # training image size
    device="cpu",  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 83.5MB/s]
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/drive/MyDrive/Colab Notebooks/YOLO11n/runs/detect/train/weights/best.pt")

# Perform object detection on an image
results = model("/content/drive/MyDrive/Colab Notebooks/YOLO11n/test_images/0.jpg", save=True)
results[0].show()
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/YOLO11n/test_images/0.jpg: 160x224 (no detections), 28.0ms
# Speed: 0.7ms preprocess, 28.0ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 224)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=910x607>

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.4/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate
# Out:
# /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate

# %%
# !ls
# Out:
# data.yaml	    README.roboflow.txt  test	valid
# README.dataset.txt  runs		 train	yolo11n.pt

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate

# !yolo task=detect mode=train model=yolo11n.pt data= data.yaml epochs=10 imgsz=224 plots=True
# Out:
# /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml		labels.jpg   train_batch0.jpg  train_batch2.jpg
# labels_correlogram.jpg	results.csv  train_batch1.jpg  weights

# %%
Image(filename='/content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/runs/detect/train3/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/runs/detect/train3/results.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/runs/detect/train3/val_batch0_pred.jpg', width=600)

# %% [markdown]
# ##Validate Custom Model

# %%
# !yolo task=detect mode=val model= runs/detect/train3/weights/best.pt data=data.yaml
# Out:
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 28.1±5.8 MB/s, size: 58.2 KB)
# val: Scanning /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/valid/labels.cache... 77 images, 0 backgrounds, 0 corrupt: 100% 77/77 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:03<00:00,  1.53it/s]
#                    all         77         99      0.782      0.465      0.539      0.367
# Speed: 0.4ms preprocess, 27.1ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ##Inference with Custom Model

# %%
# !yolo task=detect mode=predict model= runs/detect/train3/weights/best.pt conf=0.25 source= test/images
# Out:
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/90 /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test/images/000f52302c1341eb_jpg.rf.028c5ec713dda16a298af755e43e1847.jpg: 224x224 2 License_Plates, 34.6ms
# image 2/90 /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test/images/000f52302c1341eb_jpg.rf.29cc5f70f606094945c455534882ae09.jpg: 224x224 1 License_Plate, 49.4ms
# image 3/90 /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test/images/000f52302c1341eb_jpg.rf.3517025d7c272bfbd8678ff3b6ff6c18.jpg: 224x224 2 License_Plates, 28.7ms
# image 4/90 /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test/images/00a09b822d470896_jpg.rf.30d8a46ffc963b12636f5e9cf2feed17.jpg: 224x224 2 License_Plates, 28.2ms
# ...

# %%
# !yolo task=detect mode=predict model= runs/detect/train3/weights/best.pt conf=0.25 source= test_images
# Out:
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/12 /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test_images/0.jpg: 160x224 1 License_Plate, 29.1ms
# image 2/12 /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test_images/1.jpg: 128x224 1 License_Plate, 23.1ms
# image 3/12 /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test_images/10.jpg: 224x192 1 License_Plate, 28.7ms
# image 4/12 /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test_images/11.jpg: 224x192 1 License_Plate, 23.6ms
# image 5/12 /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test_images/12.jpg: 160x224 (no detections), 39.2ms
# image 6/12 /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test_images/2.jpg: 192x224 2 License_Plates, 44.1ms
# ...

# %%
# !yolo task=detect mode=predict model= runs/detect/train3/weights/best.pt conf=0.25 source= test_videos
# Out:
# Ultralytics 8.3.139 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# video 1/2 (frame 1/258) /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test_videos/2.mp4: 128x224 1 License_Plate, 24.3ms
# video 1/2 (frame 2/258) /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test_videos/2.mp4: 128x224 1 License_Plate, 24.6ms
# video 1/2 (frame 3/258) /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test_videos/2.mp4: 128x224 1 License_Plate, 24.1ms
# video 1/2 (frame 4/258) /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test_videos/2.mp4: 128x224 1 License_Plate, 23.7ms
# video 1/2 (frame 5/258) /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test_videos/2.mp4: 128x224 1 License_Plate, 22.4ms
# video 1/2 (frame 6/258) /content/drive/MyDrive/Colab Notebooks/YOLO11n/LicensePlate/test_videos/2.mp4: 128x224 1 License_Plate, 24.1ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('runs/detect/predict/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
